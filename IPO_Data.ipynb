# %%
# Stock IPO Data Analysis - Anmol Arun

# %%
# Objective: Develop a predictive model to estimate the listing price of an IPO based on features such as subscription, GMP, and IPO size.

# %%
ipo_df="/content/drive/MyDrive/Dataset/Mainline IPO GMP Performance.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
ipo_df = pd.read_csv(ipo_df)

# %%
ipo_df
# Out:
#                                              IPO Listing Date  IPO_Size  \
# 0         ASK Automotive IPO (ASKAUTOLTD,544022)   15-11-2023    834.00
# 1         Protean eGov Technologies IPO (544021)   13-11-2023    490.33
# 2        ESAF Small Finance IPO (ESAFSFB,544020)   10-11-2023    463.00
# 3    Honasa Consumer Limited IPO (HONASA,544014)   07-11-2023   1701.44
# 4         Cello World Limited IPO (CELLO,544012)   06-11-2023   1900.00
# ..                                           ...          ...       ...
# 147                  UTI AMC IPO (UTIAMC,543238)   12-10-2020   8420.74
# 148                         CAMS IPO (NA,543232)   01-10-2020   2242.00
# 149                 Chemcon IPO (CHEMCON,543233)   01-10-2020    284.00
# 150                         Angel Broking IPO ()   05-10-2020    600.00
# 151              Route Mobile IPO (ROUTE,543228)   21-09-2020    600.00
#
#      Subscription  GMP  IPO Price  Estimated Price  Estimated Percentage  \
# 0           51.14   28        282              310                  9.93
# 1           23.86   48        792              840                  6.06
# 2           77.00   16         60               76                 26.67
# 3            7.61   24        324              348                  7.41
# 4           41.69  160        648              808                 24.69
# ..            ...  ...        ...              ...                   ...
# 147          2.31  -14        554              540                 -2.53
# 148         46.99  328       1230             1558                 26.67
# 149        149.30  310        340              650                 91.18
# 150          3.94   -5        306              301                 -1.63
# 151         73.30  310        350              660                 88.57
#
#      Listing Price  Listing Percentage  LT Price  LT Percentage
# 0              303                7.55     294.0           4.43
# 1              792                0.00    1109.0          40.04
# 2               71               18.33      68.0          13.58
# 3              330                1.85     475.0          46.64
# 4              829               27.93     781.0          20.54
# ..             ...                 ...       ...            ...
# 147            500               -9.75     790.0          42.62
# 148           1518               23.41    2786.0         126.54
# 149            731              115.00     264.0         -22.35
# 150            275              -10.13       NaN            NaN
# 151            717              104.86    1540.0         340.10
#
# [152 rows x 12 columns]

# %%
ipo_df.set_index("Listing Date")
# Out:
#                                                       IPO  IPO_Size  \
# Listing Date
# 15-11-2023         ASK Automotive IPO (ASKAUTOLTD,544022)    834.00
# 13-11-2023         Protean eGov Technologies IPO (544021)    490.33
# 10-11-2023        ESAF Small Finance IPO (ESAFSFB,544020)    463.00
# 07-11-2023    Honasa Consumer Limited IPO (HONASA,544014)   1701.44
# 06-11-2023         Cello World Limited IPO (CELLO,544012)   1900.00
# ...                                                   ...       ...
# 12-10-2020                    UTI AMC IPO (UTIAMC,543238)   8420.74
# 01-10-2020                           CAMS IPO (NA,543232)   2242.00
# 01-10-2020                   Chemcon IPO (CHEMCON,543233)    284.00
# 05-10-2020                           Angel Broking IPO ()    600.00
# 21-09-2020                Route Mobile IPO (ROUTE,543228)    600.00
#
#               Subscription  GMP  IPO Price  Estimated Price  \
# Listing Date
# 15-11-2023           51.14   28        282              310
# 13-11-2023           23.86   48        792              840
# 10-11-2023           77.00   16         60               76
# 07-11-2023            7.61   24        324              348
# 06-11-2023           41.69  160        648              808
# ...                    ...  ...        ...              ...
# 12-10-2020            2.31  -14        554              540
# 01-10-2020           46.99  328       1230             1558
# 01-10-2020          149.30  310        340              650
# 05-10-2020            3.94   -5        306              301
# 21-09-2020           73.30  310        350              660
#
#               Estimated Percentage  Listing Price  Listing Percentage  \
# Listing Date
# 15-11-2023                    9.93            303                7.55
# 13-11-2023                    6.06            792                0.00
# 10-11-2023                   26.67             71               18.33
# 07-11-2023                    7.41            330                1.85
# 06-11-2023                   24.69            829               27.93
# ...                            ...            ...                 ...
# 12-10-2020                   -2.53            500               -9.75
# 01-10-2020                   26.67           1518               23.41
# 01-10-2020                   91.18            731              115.00
# 05-10-2020                   -1.63            275              -10.13
# 21-09-2020                   88.57            717              104.86
#
#               LT Price  LT Percentage
# Listing Date
# 15-11-2023       294.0           4.43
# 13-11-2023      1109.0          40.04
# 10-11-2023        68.0          13.58
# 07-11-2023       475.0          46.64
# 06-11-2023       781.0          20.54
# ...                ...            ...
# 12-10-2020       790.0          42.62
# 01-10-2020      2786.0         126.54
# 01-10-2020       264.0         -22.35
# 05-10-2020         NaN            NaN
# 21-09-2020      1540.0         340.10
#
# [152 rows x 11 columns]

# %%
ipo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IPO                   152 non-null    object
#  1   Listing Date          152 non-null    object
#  2   IPO_Size              152 non-null    float64
#  3   Subscription          152 non-null    float64
#  4   GMP                   152 non-null    int64
#  5   IPO Price             152 non-null    int64
#  6   Estimated Price       152 non-null    int64
#  7   Estimated Percentage  152 non-null    float64
#  8   Listing Price         152 non-null    int64
#  9   Listing Percentage    152 non-null    float64
#  10  LT Price              143 non-null    float64
#  11  LT Percentage         143 non-null    float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 14.4+ KB

# %%
ipo_df.isna().sum()
# Out:
# IPO                     0
# Listing Date            0
# IPO_Size                0
# Subscription            0
# GMP                     0
# IPO Price               0
# Estimated Price         0
# Estimated Percentage    0
# Listing Price           0
# Listing Percentage      0
# LT Price                9
# LT Percentage           9
# dtype: int64

# %%
ipo_df.fillna(ipo_df.mean(), inplace=True)
# Out:
# <ipython-input-32-5c331a42b6a4>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipo_df.fillna(ipo_df.mean(), inplace=True)

# %%
ipo_df
# Out:
#                                              IPO Listing Date  IPO_Size  \
# 0         ASK Automotive IPO (ASKAUTOLTD,544022)   15-11-2023    834.00
# 1         Protean eGov Technologies IPO (544021)   13-11-2023    490.33
# 2        ESAF Small Finance IPO (ESAFSFB,544020)   10-11-2023    463.00
# 3    Honasa Consumer Limited IPO (HONASA,544014)   07-11-2023   1701.44
# 4         Cello World Limited IPO (CELLO,544012)   06-11-2023   1900.00
# ..                                           ...          ...       ...
# 147                  UTI AMC IPO (UTIAMC,543238)   12-10-2020   8420.74
# 148                         CAMS IPO (NA,543232)   01-10-2020   2242.00
# 149                 Chemcon IPO (CHEMCON,543233)   01-10-2020    284.00
# 150                         Angel Broking IPO ()   05-10-2020    600.00
# 151              Route Mobile IPO (ROUTE,543228)   21-09-2020    600.00
#
#      Subscription  GMP  IPO Price  Estimated Price  Estimated Percentage  \
# 0           51.14   28        282              310                  9.93
# 1           23.86   48        792              840                  6.06
# 2           77.00   16         60               76                 26.67
# 3            7.61   24        324              348                  7.41
# 4           41.69  160        648              808                 24.69
# ..            ...  ...        ...              ...                   ...
# 147          2.31  -14        554              540                 -2.53
# 148         46.99  328       1230             1558                 26.67
# 149        149.30  310        340              650                 91.18
# 150          3.94   -5        306              301                 -1.63
# 151         73.30  310        350              660                 88.57
#
#      Listing Price  Listing Percentage     LT Price  LT Percentage
# 0              303                7.55   294.000000       4.430000
# 1              792                0.00  1109.000000      40.040000
# 2               71               18.33    68.000000      13.580000
# 3              330                1.85   475.000000      46.640000
# 4              829               27.93   781.000000      20.540000
# ..             ...                 ...          ...            ...
# 147            500               -9.75   790.000000      42.620000
# 148           1518               23.41  2786.000000     126.540000
# 149            731              115.00   264.000000     -22.350000
# 150            275              -10.13   708.664336      70.294056
# 151            717              104.86  1540.000000     340.100000
#
# [152 rows x 12 columns]

# %%
ipo_df.isna().sum()
# Out:
# IPO                     0
# Listing Date            0
# IPO_Size                0
# Subscription            0
# GMP                     0
# IPO Price               0
# Estimated Price         0
# Estimated Percentage    0
# Listing Price           0
# Listing Percentage      0
# LT Price                0
# LT Percentage           0
# dtype: int64

# %%
ipo_df.corr()
# Out:
# <ipython-input-37-247cdbb4d3ae>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipo_df.corr()
#                       IPO_Size  Subscription       GMP  IPO Price  \
# IPO_Size              1.000000     -0.199234 -0.097559   0.441196
# Subscription         -0.199234      1.000000  0.610436  -0.029750
# GMP                  -0.097559      0.610436  1.000000   0.428389
# IPO Price             0.441196     -0.029750  0.428389   1.000000
# Estimated Price       0.302841      0.212718  0.716705   0.937174
# Estimated Percentage -0.209279      0.886358  0.677216  -0.039907
# Listing Price         0.278103      0.228912  0.740861   0.911005
# Listing Percentage   -0.172930      0.768767  0.612280  -0.025875
# LT Price              0.017481      0.136020  0.344420   0.593818
# LT Percentage        -0.159638      0.286020  0.041448  -0.138059
#
#                       Estimated Price  Estimated Percentage  Listing Price  \
# IPO_Size                     0.302841             -0.209279       0.278103
# Subscription                 0.212718              0.886358       0.228912
# GMP                          0.716705              0.677216       0.740861
# IPO Price                    0.937174             -0.039907       0.911005
# Estimated Price              1.000000              0.230662       0.989130
# Estimated Percentage         0.230662              1.000000       0.260785
# Listing Price                0.989130              0.260785       1.000000
# Listing Percentage           0.216421              0.920001       0.283377
# LT Price                     0.591271              0.114065       0.562933
# LT Percentage               -0.090549              0.255637      -0.094232
#
#                       Listing Percentage  LT Price  LT Percentage
# IPO_Size                       -0.172930  0.017481      -0.159638
# Subscription                    0.768767  0.136020       0.286020
# GMP                             0.612280  0.344420       0.041448
# IPO Price                      -0.025875  0.593818      -0.138059
# Estimated Price                 0.216421  0.591271      -0.090549
# Estimated Percentage            0.920001  0.114065       0.255637
# Listing Price                   0.283377  0.562933      -0.094232
# Listing Percentage              1.000000  0.071836       0.171759
# LT Price                        0.071836  1.000000       0.443941
# LT Percentage                   0.171759  0.443941       1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['IPO_Size'].plot(kind='hist', bins=20, title='IPO_Size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Subscription'].plot(kind='hist', bins=20, title='Subscription')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['GMP'].plot(kind='hist', bins=20, title='GMP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['IPO Price'].plot(kind='hist', bins=20, title='IPO Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='IPO_Size', y='Subscription', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Subscription', y='GMP', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='GMP', y='IPO Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='IPO Price', y='Estimated Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['IPO_Size'].plot(kind='line', figsize=(8, 4), title='IPO_Size')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Subscription'].plot(kind='line', figsize=(8, 4), title='Subscription')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['GMP'].plot(kind='line', figsize=(8, 4), title='GMP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['IPO Price'].plot(kind='line', figsize=(8, 4), title='IPO Price')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
f = plt.figure(figsize=(5, 5))
plt.matshow(ipo_df.corr(), fignum=f.number)
cb = plt.colorbar()
# Out:
# <ipython-input-41-10501dbe44b9>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(ipo_df.corr(), fignum=f.number)

# %%
ipo_df.describe()
# Out:
#            IPO_Size  Subscription          GMP    IPO Price  Estimated Price  \
# count    152.000000    152.000000   152.000000   152.000000       152.000000
# mean    1514.503829     46.681579   106.105263   455.888158       561.993421
# std     2615.125391     59.536088   182.924012   365.665999       473.795279
# min       60.000000      0.120000   -80.000000    25.000000        26.000000
# 25%      490.667500      3.612500     4.750000   184.000000       225.500000
# 50%      747.500000     21.700000    36.500000   348.000000       439.500000
# 75%     1398.760000     72.272500   125.500000   595.000000       766.750000
# max    20557.000000    326.490000  1110.000000  2150.000000      2240.000000
#
#        Estimated Percentage  Listing Price  Listing Percentage     LT Price  \
# count            152.000000     152.000000          152.000000   152.000000
# mean              24.305263     565.361842           24.816118   708.664336
# std               30.306422     488.955293           38.638264   675.736840
# min              -11.000000      25.000000          -23.730000    38.000000
# 25%                1.912500     218.750000            0.277500   272.500000
# 50%               11.605000     437.000000           12.455000   543.500000
# 75%               38.837500     752.500000           37.952500   843.500000
# max              138.040000    2607.000000          249.690000  5123.000000
#
#        LT Percentage
# count     152.000000
# mean       70.294056
# std       134.343405
# min       -84.740000
# 25%         4.277500
# 50%        47.825000
# 75%        83.215000
# max      1306.790000

# %%
import seaborn
import plotly.express as px

# %%
fig = px.scatter(ipo_df,
                 x='IPO Price',
                 y='Listing Price',
                 opacity=0.8,
                 hover_data=['IPO Price'],
                 title='GMP vs LT Price')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73fb417a-06d8-4982-a0ab-c4e065502afe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73fb417a-06d8-4982-a0ab-c4e065502afe")) {                    Plotly.newPlot(                        "73fb417a-06d8-4982-a0ab-c4e065502afe",                        [{"hovertemplate":"IPO Price=%{x}\u003cbr\u003eListing Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle","size":5},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[282,792,60,324,648,346,505,54,140,300,119,215,142,222,385,126,164,211,1035,735,98,441,99,108,166,197,741,57,300,500,25,317,265,672,585,285,1080,436,35,140,590,65,99,247,366,506,270,357,577,237,541,65,587,407,474,336,300,368,207,80,59,330,525,326,220,642,256,878,42,487,326,630,949,542,292,137,153,68,866,230,175,216,274,274,585,796,500,1033,118,425,550,453,900,690,662,197,1180,2150,542,163,980,1125,712,175,744,610,531,353,541,570,1618,90,954,460,120,900,720,1083,76,837,900,296,825,428,306,291,87,305,1101,130,1490,555,187,575,627,400,94,385,518,1490,26,315,288,60,1500,120,145,554,1230,340,306,350],"xaxis":"x","y":[303,792,71,330,829,380,477,76,162,285,143,215,128,231,444,134,164,282,1180,973,123,460,165,190,187,207,900,82,306,947,40,430,403,1300,625,392,1300,436,30,164,620,85,104,244,367,471,273,358,575,266,555,60,778,450,465,401,323,360,287,84,90,450,510,509,262,704,270,830,44,495,335,650,872,510,360,157,220,76,935,227,175,220,421,315,856,1040,437,1565,90,360,600,760,845,1310,682,512,1350,1950,542,570,1150,2018,715,475,812,910,540,333,550,485,1599,141,1005,437,126,1250,750,2111,116,1715,1755,350,1009,550,380,301,74,292,1990,156,1359,520,212,1050,900,615,109,467,612,2607,25,430,505,115,1710,130,215,500,1518,731,275,717],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4 ...

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
def rmse(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

# %%
from sklearn.metrics import accuracy_score

# %%
# Create inputs and targets
input_cols = ['GMP', 'IPO Price', 'Estimated Price', 'Estimated Percentage', 'IPO_Size', 'Subscription']
inputs, targets = ipo_df[input_cols], ipo_df['Listing Price']

# Create and train the model
model = LinearRegression().fit(inputs, targets)

# Generate predictions
predictions = model.predict(inputs)

# Compute loss to evalute the model
loss = rmse(targets, predictions)
print('Loss:', loss)
# Out:
# Loss: 67.14669179571625

# %%
from sklearn.model_selection import train_test_split

# %%
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.1)

# %%
# Create and train the model
model = LinearRegression().fit(inputs_train, targets_train)

# Generate predictions
predictions_test = model.predict(inputs_test)

# Compute loss to evalute the model
loss = rmse(targets_test, predictions_test)
print('Test Loss:', loss)
# Out:
# Test Loss: 78.67665620189102

# %%
# Generate predictions
predictions_train = model.predict(inputs_train)

# Compute loss to evalute the model
loss = rmse(targets_train, predictions_train)
print('Training Loss:', loss)
# Out:
# Training Loss: 66.87585501348772

# %%
from sklearn.preprocessing import StandardScaler

# %%
numeric_cols = ['GMP', 'IPO Price', 'Estimated Price', 'Estimated Percentage', 'IPO_Size', 'Subscription']
scaler = StandardScaler()
scaler.fit(ipo_df[numeric_cols])
# Out:
# StandardScaler()

# %%
scaled_inputs = scaler.transform(ipo_df[numeric_cols])
#         -2.25290863e-01, -5.42681392e-01, -1.13778020e-01],
#        [-5.27120340e-01, -9.92940241e-01, -9.69843882e-01,
#         -4.52393810e-01, -2.66741408e-01, -7.23219503e-02],
#        [-3.89999770e-01, -1.94501265e-01, -3.00684342e-01,
#         -5.03707158e-01, -4.22739346e-01, -4.82838157e-01],
#        [ 7.62101696e-02,  1.70421016e-01,  1.60951036e-01,
#         -3.75833249e-02, -1.38416501e-01, -3.37404870e-01],
#        [ 3.53164854e+00,  2.83737182e+00,  3.55333579e+00,
#          8.61890009e-01, -1.29868669e-01,  1.18534736e+00],
#        [-5.81968568e-01, -1.17951705e+00, -1.13501617e+00,
#         -7.71529729e-01,  1.19657227e+00, -7.27867124e-01],
#        [ 3.77875424e-01, -3.86565624e-01, -1.52452799e-01,
#          1.03470012e+00, -4.65954239e-01, -5.33225819e-01],
#        [ 5.97268337e-01, -4.60647590e-01, -1.24924084e-01,
#          1.66668194e+00, -3.73666041e-01,  2.55036431e+00],
#        [-3.46121187e-01, -1.08622864e+00, -9.71961475e-01,
#          1.56802789e+00, -2.70286379e-01,  1.85319454e+00],
#        [ 6.52405240e-02,  2.86480959e+00,  2.23619265e+00,
#         -5.44095728e-01,  1.90486453e+00, -7.51965571e-01],
#        [-5.49059631e-01, -9.21602051e-01, -9.23256825e-01,
#         -6.39108186e-01, -5.57567204e-01, -6.26417717e-01],
#        [-6.06217259e-03, -8.53007637e-01, -6.60675234e-01,
#          1.59252587e+00, -4.10823023e-01,  1.86600211e+00],
#        [-6.58756088e-01,  2.69196972e-01, -4.65731250e-02,
#         -8.88391741e-01,  2.64961167e+00, -7.47752556e-01],
#        [ 1.21705332e+00,  2.12398992e+00,  2.10913704e+00,
#          7.82855256e-02,  2.79107505e-01,  5.19753040e-03],
#        [ 1.11832650e+00, -3.17971210e-01,  1.86362158e-01,
#          2.21391397e+00, -4.72088882e-01,  1.72933189e+00],
#        [-6.09392682e-01, -4.11259613e-01, -5.52677966e-01,
#         -8.58596894e-01, -3.50853918e-01, -7.20283696e-01],
#        [ 1.11832650e+00, -2.90533444e-01,  2.07538092e-01,
#          2.12750891e+00, -3.50853918e-01,  4.48575256e-01]])

# %%
inputs = scaled_inputs
targets = ipo_df["Listing Price"]

# Create and train the model
model = LinearRegression().fit(inputs, targets)

# Generate predictions
predictions = model.predict(inputs)

# Compute loss to evalute the model
loss = rmse(targets, predictions)
print('Loss:', loss)
# Out:
# Loss: 67.14669179571624

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=11)
regr_1.fit(inputs, targets)
regr_2.fit(inputs, targets)
# Out:
# DecisionTreeRegressor(max_depth=11)

# %%
y_1 = regr_1.predict(inputs)
y_2 = regr_2.predict(inputs)

# %%
loss = rmse(targets, y_1)
print('Loss:', loss)
# Out:
# Loss: 151.30931623896828

# %%
loss = rmse(targets, y_2)
print('Loss:', loss)
# Out:
# Loss: 0.36724436149875955
